# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Supermarket.xlsx')

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    765-26-6951      A     Yangon        Normal    Male
# 1    530-90-9855      A     Yangon        Member    Male
# 2    891-01-7034      B   Mandalay        Normal  Female
# 3    493-65-6248      C  Naypyidaw        Member  Female
# 4    556-97-7101      C  Naypyidaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 995  642-61-4706      B   Mandalay        Member    Male
# 996  115-38-7388      C  Naypyidaw        Member  Female
# 997  291-55-6563      A     Yangon        Member  Female
# 998  361-85-2571      A     Yangon        Normal  Female
# 999  364-34-2972      C  Naypyidaw        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0         Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1        Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# ...

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data['Invoice ID'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Invoice ID, Length: 1000, dtype: bool

# %%
data['Product line'].unique()
# Out:
# array(['Sports and travel', 'Home and lifestyle',
#        'Electronic accessories', 'Health and beauty',
#        'Fashion accessories', 'Food and beverages'], dtype=object)

# %%
data['City'].unique()
# Out:
# array(['Yangon', 'Mandalay', 'Naypyidaw'], dtype=object)

# %%
data.groupby('City')['Branch'].unique()
# Out:
# City
# Mandalay     [B]
# Naypyidaw    [C]
# Yangon       [A]
# Name: Branch, dtype: object

# %% [markdown]
# # Every branch in each city is unique by A,B,C
# ## Yangon(A), Naypyidaw(C), Mandalay(B).

# %%
data.groupby('Product line')['cogs'].sum()
# Out:
# Product line
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Food and beverages        53471.28
# Health and beauty         46851.18
# Home and lifestyle        51297.06
# Sports and travel         52497.93
# Name: cogs, dtype: float64

# %%
data.groupby('Product line')['cogs'].sum().plot(kind = 'bar' ,color = 'gold')
plt.show()

# %% [markdown]
# # Food and Beverages is most sold product

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyidaw        Member  Female
# 4  556-97-7101      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
data['Date'].unique()
# Out:
# array(['2019-01-01T00:00:00.000000000', '2019-01-02T00:00:00.000000000',
#        '2019-01-03T00:00:00.000000000', '2019-01-04T00:00:00.000000000',
#        '2019-01-05T00:00:00.000000000', '2019-01-06T00:00:00.000000000',
#        '2019-01-07T00:00:00.000000000', '2019-01-08T00:00:00.000000000',
#        '2019-01-09T00:00:00.000000000', '2019-01-10T00:00:00.000000000',
#        '2019-01-11T00:00:00.000000000', '2019-01-12T00:00:00.000000000',
#        '2019-01-13T00:00:00.000000000', '2019-01-14T00:00:00.000000000',
#        '2019-01-15T00:00:00.000000000', '2019-01-16T00:00:00.000000000',
#        '2019-01-17T00:00:00.000000000', '2019-01-18T00:00:00.000000000',
#        '2019-01-19T00:00:00.000000000', '2019-01-20T00:00:00.000000000',
#        '2019-01-21T00:00:00.000000000', '2019-01-22T00:00:00.000000000',
#        '2019-01-23T00:00:00.000000000', '2019-01-24T00:00:00.000000000',
#        '2019-01-25T00:00:00.000000000', '2019-01-26T00:00:00.000000000',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
data['Date'].dt.date
# Out:
# 0      2019-01-01
# 1      2019-01-01
# 2      2019-01-01
# 3      2019-01-01
# 4      2019-01-01
#           ...
# 995    2019-03-30
# 996    2019-03-30
# 997    2019-03-30
# 998    2019-03-30
# 999    2019-03-30
# Name: Date, Length: 1000, dtype: object

# %%
data['Date2'] = data['Date'].dt.date

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    765-26-6951      A     Yangon        Normal    Male
# 1    530-90-9855      A     Yangon        Member    Male
# 2    891-01-7034      B   Mandalay        Normal  Female
# 3    493-65-6248      C  Naypyidaw        Member  Female
# 4    556-97-7101      C  Naypyidaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 995  642-61-4706      B   Mandalay        Member    Male
# 996  115-38-7388      C  Naypyidaw        Member  Female
# 997  291-55-6563      A     Yangon        Member  Female
# 998  361-85-2571      A     Yangon        Normal  Female
# 999  364-34-2972      C  Naypyidaw        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0         Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1        Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
data['Date2'].unique()
# Out:
# array([datetime.date(2019, 1, 1), datetime.date(2019, 1, 2),
#        datetime.date(2019, 1, 3), datetime.date(2019, 1, 4),
#        datetime.date(2019, 1, 5), datetime.date(2019, 1, 6),
#        datetime.date(2019, 1, 7), datetime.date(2019, 1, 8),
#        datetime.date(2019, 1, 9), datetime.date(2019, 1, 10),
#        datetime.date(2019, 1, 11), datetime.date(2019, 1, 12),
#        datetime.date(2019, 1, 13), datetime.date(2019, 1, 14),
#        datetime.date(2019, 1, 15), datetime.date(2019, 1, 16),
#        datetime.date(2019, 1, 17), datetime.date(2019, 1, 18),
#        datetime.date(2019, 1, 19), datetime.date(2019, 1, 20),
#        datetime.date(2019, 1, 21), datetime.date(2019, 1, 22),
#        datetime.date(2019, 1, 23), datetime.date(2019, 1, 24),
#        datetime.date(2019, 1, 25), datetime.date(2019, 1, 26),
#        datetime.date(2019, 1, 27), datetime.date(2019, 1, 28),
#        datetime.date(2019, 1, 29), datetime.date(2019, 1, 30),
# ...

# %%
'(2019, 1, 1)'.split(',')
# Out:
# ['(2019', ' 1', ' 1)']

# %%
def Months(x):
    return x.split(',')[1]

# %%
data['Months'] =pd.to_datetime(data['Date2']).dt.month

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyidaw        Member  Female
# 4  556-97-7101      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
data.drop('Date', axis = 1, inplace = True)

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyidaw        Member  Female
# 4  556-97-7101      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total      Time  \
# 0       Sports and travel       72.61         6  21.783  457.443  10:39:00
# 1      Home and lifestyle       47.59         8  19.036  399.756  14:47:00
# 2  Electronic accessories       74.71         6  22.413  470.673  19:07:00
# 3       Sports and travel       36.98        10  18.490  388.290  19:48:00
# 4  Electronic accessories       63.22         2   6.322  132.762  15:51:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  Credit card  435.66                 4.761905        21.783     6.9
# ...

# %%
data = data.rename(columns = {'Date2':'Date'})

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyidaw        Member  Female
# 4  556-97-7101      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total      Time  \
# 0       Sports and travel       72.61         6  21.783  457.443  10:39:00
# 1      Home and lifestyle       47.59         8  19.036  399.756  14:47:00
# 2  Electronic accessories       74.71         6  22.413  470.673  19:07:00
# 3       Sports and travel       36.98        10  18.490  388.290  19:48:00
# 4  Electronic accessories       63.22         2   6.322  132.762  15:51:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  Credit card  435.66                 4.761905        21.783     6.9
# ...

# %%
data.groupby('Months')['gross income'].sum()
# Out:
# Months
# 1    5537.708
# 2    4629.494
# 3    5212.167
# Name: gross income, dtype: float64

# %%
months = range(1,4)
plt.bar(months, data.groupby('Months')['gross income'].sum(), color = 'b')
plt.xlabel('Months')
plt.ylabel('Gross income')
plt.show()

# %% [markdown]
# # Sales are greater in the first month

# %%
city = data.groupby('gross income')['Branch'].sum()

# %%
product = data.groupby('Product line')['gross income'].sum()

# %%
df = data.pivot_table(index = 'City', columns = 'Product line', values ='gross income', aggfunc = 'sum')

# %%
df
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# City
# Mandalay                    811.9735             781.5865            724.5185
# Naypyidaw                   903.2845            1026.6700           1131.7550
# Yangon                      872.2435             777.7385            817.2905
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# City
# Mandalay                951.460            835.6745           951.8190
# Naypyidaw               791.206            661.6930           750.5680
# Yangon                  599.893           1067.4855           922.5095

# %%
df.plot(kind = 'bar', figsize = (8,8))
plt.ylabel('Goods Count')
plt.legend(fontsize ='6.6')

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Time',
#        'Payment', 'cogs', 'gross margin percentage', 'gross income', 'Rating',
#        'Date', 'Months'],
#       dtype='object')

# %%
feature = ['City','Customer type','Gender','Months']

# %%
list(enumerate(feature))
# Out:
# [(0, 'City'), (1, 'Customer type'), (2, 'Gender'), (3, 'Months')]

# %%
plt.figure(figsize = (15,30))
for i in enumerate(feature):
    plt.subplot(3,2,i[0]+1)
    ax = sns.countplot(i[1], hue = 'Product line', data = data)
    plt.setp(ax. get_legend() .get_texts(), fontsize = '6.6')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Quantity of Goods ordered in each city, by Customer type, By Gender and By Months

# %%
data.groupby('Product line')['gross income'].sum()
# Out:
# Product line
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Food and beverages        2673.5640
# Health and beauty         2342.5590
# Home and lifestyle        2564.8530
# Sports and travel         2624.8965
# Name: gross income, dtype: float64

# %%
data.groupby('Product line')['gross income'].sum().plot(kind = 'bar')
plt.show()

# %%
data['Time'].unique()
# Out:
# array([datetime.time(10, 39), datetime.time(14, 47), datetime.time(19, 7),
#        datetime.time(19, 48), datetime.time(15, 51),
#        datetime.time(11, 43), datetime.time(13, 55),
#        datetime.time(20, 26), datetime.time(14, 42),
#        datetime.time(11, 40), datetime.time(19, 31),
#        datetime.time(11, 36), datetime.time(16, 57), datetime.time(18, 9),
#        datetime.time(13, 0), datetime.time(13, 40), datetime.time(18, 50),
#        datetime.time(15, 24), datetime.time(16, 19), datetime.time(20, 8),
#        datetime.time(12, 2), datetime.time(19, 17), datetime.time(16, 47),
#        datetime.time(10, 30), datetime.time(13, 7), datetime.time(20, 24),
#        datetime.time(19, 8), datetime.time(19, 40), datetime.time(18, 19),
#        datetime.time(13, 24), datetime.time(13, 34), datetime.time(19, 1),
#        datetime.time(13, 21), datetime.time(13, 8), datetime.time(20, 54),
#        datetime.time(11, 25), datetime.time(16, 5), datetime.time(19, 50),
# ...

# %%
data['Time'].dtype
# Out:
# dtype('O')

# %%
'(10, 39)'.split(',')
# Out:
# ['(10', ' 39)']

# %%
def Hour(x):
    return x.split(',')[0]

# %%
data['Time'] = pd.to_datetime(data['Time'], format = '%H:%M:%S')

# %%
data['Hour'] = pd.to_datetime(data['Time'], format = '%H').dt.hour

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyidaw        Member  Female
# 4  556-97-7101      C  Naypyidaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total  \
# 0       Sports and travel       72.61         6  21.783  457.443
# 1      Home and lifestyle       47.59         8  19.036  399.756
# 2  Electronic accessories       74.71         6  22.413  470.673
# 3       Sports and travel       36.98        10  18.490  388.290
# 4  Electronic accessories       63.22         2   6.322  132.762
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 1900-01-01 10:39:00  Credit card  435.66                 4.761905
# 1 1900-01-01 14:47:00         Cash  380.72                 4.761905
# ...

# %%
keys = []
hours = []
for key, hour_df in data.groupby('Hour'):
    keys.append(key)
    hours.append(len(hour_df))

# %%
keys
hours
plt.plot(keys, hours)
plt.xlabel('Hours')
plt.ylabel('COGS')
plt.grid()

# %% [markdown]
# # There is an increase in sales between 17:00 hour to 20:00 hour of the day

# %%
data.groupby('Hour')['cogs'].sum().plot(kind = 'bar', title = 'Cost of Goods sold per Hour', color = 'green')
plt.show()

# %% [markdown]
# # The supermarket makes more sales at 19:00 hour of the day

# %%
data.groupby('City')['Payment'].unique()
# Out:
# City
# Mandalay     [Cash, Credit card, Ewallet]
# Naypyidaw    [Credit card, Cash, Ewallet]
# Yangon       [Credit card, Cash, Ewallet]
# Name: Payment, dtype: object

# %% [markdown]
# # To check if all payment platform is available in the three cities

# %%
df1 = data.pivot_table(index = 'Branch', columns = 'City', values ='Payment', aggfunc = 'count')

# %%
df1
# Out:
# City    Mandalay  Naypyidaw  Yangon
# Branch
# A            NaN        NaN   340.0
# B          332.0        NaN     NaN
# C            NaN      328.0     NaN

# %%
data.groupby('City')['Customer type'].count()
# Out:
# City
# Mandalay     332
# Naypyidaw    328
# Yangon       340
# Name: Customer type, dtype: int64

# %% [markdown]
# # To know the count of cutomers in each city

# %%
data.groupby('City')['gross income'].sum()
# Out:
# City
# Mandalay     5057.0320
# Naypyidaw    5265.1765
# Yangon       5057.1605
# Name: gross income, dtype: float64

# %%
exp = [0.01,0.1,0.01]
cl = ['green','orange','red']
data.groupby('City')['gross income'].sum().plot(kind = 'pie', ylabel = '',figsize = (10,10),autopct = '%2.1f%%',explode = exp, title = 'Percentage of Income',colors = cl)
# Out:
# <AxesSubplot:title={'center':'Percentage of Income'}>

# %% [markdown]
# # Naypyidaw city makes the highest profit.
